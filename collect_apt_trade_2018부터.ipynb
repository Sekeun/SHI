# %% [markdown]
# # 국토교통부_아파트매매_실거래자료_크롤링

# %% [markdown]
# - 데이터 출처: https://www.data.go.kr/tcs/dss/selectApiDataDetailView.do?publicDataPk=15058038
# - 지역코드 출처: 주민등록주소코드 변경내역(2018. 1. 22. 현재) https://www.mois.go.kr/frt/bbs/type001/commonSelectBoardArticle.do?bbsId=BBSMSTR_000000000052&nttId=61552 내 첨부파일 jscode20180122.zip
#
# ##### *주의: 일일 트래픽 1000회 제한*

# %%
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %% [markdown]
# ## 함수 설정

# %%
def collect_apt_trade(ym, lawd_cd) :
    
    # 제공받은 API 
    API_KEY = 'bHg%2FpafJkgCqoGEFC3cI5IvynqkFuwK53BYhBu3bqMz7I%2BX%2BEYH8R9jV%2FCMc06dm11DO%2FksvWzs5sIUeyCjiTQ%3D%3D'
    
    # URL
    url = 'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTrade'
 
    # 요청메시지
    url = url + '?&LAWD_CD=' + lawd_cd + '&DEAL_YMD=' + ym + '&serviceKey=' + API_KEY
 
    resultXML = urlopen(url)
    result = resultXML.read()
    xmlsoup = BeautifulSoup(result, 'lxml-xml')
 
    te = xmlsoup.findAll('item')
 
    # 데이터프레임 결과물
    apt_trade = pd.DataFrame()
 
    for t in te:
        deal_amt = t.find('거래금액').text
        build_y = t.find('건축년도').text
        deal_y = t.find('년').text
        deal_m = t.find('월').text
        deal_day = t.find('일').text
        dong = t.find('법정동').text
        apt_nm = t.find('아파트').text
        area_exc = t.find('전용면적').text
        
        try:
            region_num = t.find("지번").text
        except:
            region_num = ""

        region_code = t.find('지역코드').text
        floor = t.find('층').text
 
        temp = pd.DataFrame(([[deal_amt, build_y, deal_y, deal_m, deal_day, dong, apt_nm, area_exc, region_num, region_code, floor]]),
                           columns = ['deal_amt', 'build_y', 'deal_y', 'deal_m', 'deal_day', 'dong', 'apt_nm', 'area_exc', 'region_num', 'region_code', 'floor'])
        apt_trade = pd.concat([apt_trade, temp])
 
    apt_trade = apt_trade.reset_index(drop=True)
 
    return apt_trade

# %% [markdown]
# ## 수집

# %% [markdown]
# #### 수집 경과 ####
# 2019년 data => 7/16 완료
# 2020년 data => 7/19 완료
#
# ### ****2018부터 진행 예정 ****

# %%
if __name__ == "__main__":

    # 지역코드 가져오기
    code = pd.read_excel("KIKcd_B.20180122.xlsx")
    code_cap = code[(code["시도명"]=="서울특별시") | (code["시도명"] == "경기도")]
    code_cap = code_cap[code_cap["읍면동명"].isnull() == True]
    code_cap = code_cap[code_cap["시군구명"].isnull() == False]
    code_cap["region_code"] = code_cap["법정동코드"].astype(str).str[0:5]
    code_cap = code_cap.reset_index(drop=True)
    apt_trade = pd.DataFrame()

    # 기간설정(연월: 'yyyymm')
    ym = list(['201801', '201802', '201803', '201804', '201805', '201806', '201807', 
               '201808', '201809', '201810', '201811', '201812'])
 
    for m in ym:
        i = 0
        for co in code_cap['region_code'] :
            temp = collect_apt_trade(m, co)
            temp['sido'] = code_cap['시도명'][i]
            temp['sigungu'] = code_cap['시군구명'][i]
            apt_trade = pd.concat([apt_trade, temp])
            i += 1
            print(co + ", " + str(len(temp)) + "개 완료")
            
        print("******** " + str(m) + " 완료 ********")
# Out:
# 11110, 44개 완료
# 11140, 64개 완료
# 11170, 39개 완료
# 11200, 156개 완료
# 11215, 55개 완료
# 11230, 183개 완료
# 11260, 220개 완료
# 11290, 249개 완료
# 11305, 164개 완료
# 11320, 321개 완료
# 11350, 649개 완료
# 11380, 213개 완료
# 11410, 144개 완료
# 11440, 118개 완료
# 11470, 180개 완료
# 11500, 264개 완료
# 11530, 330개 완료
# 11545, 180개 완료
# 11560, 153개 완료
# 11590, 126개 완료
# 11620, 189개 완료
# 11650, 123개 완료
# 11680, 148개 완료
# 11710, 154개 완료
# 11740, 172개 완료
# 41110, 0개 완료
# 41111, 235개 완료
# 41113, 245개 완료
# 41115, 116개 완료
# 41117, 262개 완료
# 41130, 0개 완료
# 41131, 64개 완료
# 41133, 92개 완료
# 41135, 260개 완료
# 41150, 891개 완료
# 41170, 0개 완료
# 41171, 177개 완료
# 41173, 468개 완료
# 41190, 1207개 완료
# 41210, 311개 완료
# 41220, 925개 완료
# 41250, 115개 완료
# 41270, 0개 완료
# 41271, 481개 완료
# 41273, 669개 완료
# 41280, 0개 완료
# 41281, 592개 완료
# 41285, 341개 완료
# 41287, 492개 완료
# 41290, 5개 완료
# 41310, 256개 완료
# 41360, 1384개 완료
# 41370, 589개 완료
# 41390, 1044개 완료
# 41410, 660개 완료
# 41430, 187개 완료
# 41450, 178개 완료
# 41460, 0개 완료
# 41461, 300개 완료
# 41463, 606개 완료
# 41465, 341개 완료
# 41480, 459개 완료
# 41500, 160개 완료
# 41550, 267개 완료
# 41570, 787개 완료
# 41590, 1109개 완료
# 41610, 474개 완료
# 41630, 325개 완료
# 41650, 80개 완료
# 41670, 62개 완료
# 41800, 16개 완료
# 41820, 24개 완료
# 41830, 43개 완료
# ******** 202003 완료 ********
# 11110, 28개 완료
# 11140, 37개 완료
# 11170, 33개 완료
# 11200, 77개 완료
# 11215, 41개 완료
# 11230, 125개 완료
# 11260, 145개 완료
# 11290, 182개 완료
# 11305, 104개 완료
# 11320, 205개 완료
# 11350, 392개 완료
# 11380, 185개 완료
# 11410, 88개 완료
# 11440, 68개 완료
# 11470, 120개 완료
# 11500, 193개 완료
# 11530, 240개 완료
# 11545, 54개 완료
# 11560, 128개 완료
# 11590, 53개 완료
# 11620, 146개 완료
# 11650, 95개 완료
# 11680, 158개 완료
# 11710, 144개 완료
# 11740, 129개 완료
# 41110, 0개 완료
# 41111, 208개 완료
# 41113, 257개 완료
# 41115, 100개 완료
# 41117, 229개 완료
# 41130, 0개 완료
# 41131, 39개 완료
# 41133, 52개 완료
# 41135, 173개 완료
# 41150, 615개 완료
# 41170, 0개 완료
# 41171, 152개 완료
# 41173, 346개 완료
# 41190, 841개 완료
# 41210, 212개 완료
# 41220, 729개 완료
# 41250, 127개 완료
# 41270, 0개 완료
# 41271, 345개 완료
# 41273, 560개 완료
# 41280, 0개 완료
# 41281, 485개 완료
# 41285, 287개 완료
# 41287, 434개 완료
# 41290, 10개 완료
# 41310, 128개 완료
# 41360, 1014개 완료
# 41370, 380개 완료
# 41390, 825개 완료
# 41410, 351개 완료
# 41430, 121개 완료
# 41450, 101개 완료
# 41460, 0개 완료
# 41461, 248개 완료
# 41463, 552개 완료
# 41465, 273개 완료
# 41480, 357개 완료
# 41500, 138개 완료
# 41550, 261개 완료
# 41570, 585개 완료
# 41590, 917개 완료
# 41610, 447개 완료
# 41630, 311개 완료
# 41650, 72개 완료
# 41670, 55개 완료
# 41800, 12개 완료
# 41820, 17개 완료
# 41830, 43개 완료
# ******** 202004 완료 ********
# 11110, 55개 완료
# 11140, 57개 완료
# 11170, 135개 완료
# 11200, 187개 완료
# 11215, 84개 완료
# 11230, 228개 완료
# 11260, 233개 완료
# 11290, 270개 완료
# 11305, 136개 완료
# 11320, 302개 완료
# 11350, 653개 완료
# 11380, 253개 완료
# 11410, 187개 완료
# 11440, 162개 완료
# 11470, 263개 완료
# 11500, 335개 완료
# 11530, 380개 완료
# 11545, 104개 완료
# 11560, 248개 완료
# 11590, 155개 완료
# 11620, 180개 완료
# 11650, 218개 완료
# 11680, 345개 완료
# 11710, 357개 완료
# 11740, 320개 완료
# 41110, 0개 완료
# 41111, 324개 완료
# 41113, 313개 완료
# 41115, 96개 완료
# 41117, 420개 완료
# 41130, 0개 완료
# 41131, 85개 완료
# 41133, 88개 완료
# 41135, 398개 완료
# 41150, 756개 완료
# 41170, 0개 완료
# 41171, 199개 완료
# 41173, 474개 완료
# 41190, 1095개 완료
# 41210, 372개 완료
# 41220, 848개 완료
# 41250, 109개 완료
# 41270, 0개 완료
# 41271, 533개 완료
# 41273, 712개 완료
# 41280, 0개 완료
# 41281, 664개 완료
# 41285, 475개 완료
# 41287, 609개 완료
# 41290, 20개 완료
# 41310, 156개 완료
# 41360, 1297개 완료
# 41370, 463개 완료
# 41390, 999개 완료
# 41410, 445개 완료
# 41430, 167개 완료
# 41450, 230개 완료
# 41460, 0개 완료
# 41461, 309개 완료
# 41463, 720개 완료
# 41465, 579개 완료
# 41480, 452개 완료
# 41500, 172개 완료
# 41550, 328개 완료
# 41570, 738개 완료
# 41590, 1135개 완료
# 41610, 495개 완료
# 41630, 333개 완료
# 41650, 57개 완료
# 41670, 86개 완료
# 41800, 13개 완료
# 41820, 26개 완료
# 41830, 42개 완료
# ******** 202005 완료 ********
# 11110, 118개 완료
# 11140, 171개 완료
# 11170, 275개 완료
# 11200, 684개 완료
# 11215, 238개 완료
# 11230, 567개 완료
# 11260, 498개 완료
# 11290, 906개 완료
# 11305, 392개 완료
# 11320, 908개 완료
# 11350, 1836개 완료
# 11380, 579개 완료
# 11410, 494개 완료
# 11440, 504개 완료
# 11470, 722개 완료
# 11500, 1166개 완료
# 11530, 915개 완료
# 11545, 242개 완료
# 11560, 619개 완료
# 11590, 563개 완료
# 11620, 538개 완료
# 11650, 574개 완료
# 11680, 824개 완료
# 11710, 1183개 완료
# 11740, 897개 완료
# 41110, 0개 완료
# 41111, 635개 완료
# 41113, 583개 완료
# 41115, 221개 완료
# 41117, 1043개 완료
# 41130, 0개 완료
# 41131, 194개 완료
# 41133, 279개 완료
# 41135, 1575개 완료
# 41150, 1205개 완료
# 41170, 0개 완료
# 41171, 327개 완료
# 41173, 1156개 완료
# 41190, 1557개 완료
# 41210, 1132개 완료
# 41220, 1606개 완료
# 41250, 211개 완료
# 41270, 0개 완료
# 41271, 639개 완료
# 41273, 726개 완료
# 41280, 0개 완료
# 41281, 1436개 완료
# 41285, 1024개 완료
# 41287, 1877개 완료
# 41290, 62개 완료
# 41310, 348개 완료
# 41360, 2732개 완료
# 41370, 764개 완료
# 41390, 1471개 완료
# 41410, 875개 완료
# 41430, 356개 완료
# 41450, 747개 완료
# 41460, 0개 완료
# 41461, 449개 완료
# 41463, 1499개 완료
# 41465, 1410개 완료
# 41480, 1206개 완료
# 41500, 352개 완료
# 41550, 898개 완료
# 41570, 2604개 완료
# 41590, 2374개 완료
# 41610, 837개 완료
# 41630, 468개 완료
# 41650, 102개 완료
# 41670, 96개 완료
# 41800, 17개 완료
# 41820, 20개 완료
# 41830, 59개 완료
# ******** 202006 완료 ********
# 11110, 98개 완료
# 11140, 148개 완료
# 11170, 187개 완료
# 11200, 410개 완료
# 11215, 201개 완료
# 11230, 415개 완료
# 11260, 362개 완료
# 11290, 604개 완료
# 11305, 218개 완료
# 11320, 646개 완료
# 11350, 972개 완료
# 11380, 515개 완료
# 11410, 380개 완료
# 11440, 482개 완료
# 11470, 505개 완료
# 11500, 987개 완료
# 11530, 577개 완료
# 11545, 186개 완료
# 11560, 432개 완료
# 11590, 514개 완료
# 11620, 325개 완료
# 11650, 466개 완료
# 11680, 382개 완료
# 11710, 583개 완료
# 11740, 570개 완료
# 41110, 0개 완료
# 41111, 383개 완료
# 41113, 533개 완료
# 41115, 164개 완료
# 41117, 823개 완료
# 41130, 0개 완료
# 41131, 129개 완료
# 41133, 202개 완료
# 41135, 946개 완료
# 41150, 890개 완료
# 41170, 0개 완료
# 41171, 260개 완료
# 41173, 761개 완료
# 41190, 1093개 완료
# 41210, 626개 완료
# 41220, 656개 완료
# 41250, 173개 완료
# 41270, 0개 완료
# 41271, 287개 완료
# 41273, 243개 완료
# 41280, 0개 완료
# 41281, 864개 완료
# 41285, 551개 완료
# 41287, 977개 완료
# 41290, 33개 완료
# 41310, 358개 완료
# 41360, 1501개 완료
# 41370, 475개 완료
# 41390, 847개 완료
# 41410, 349개 완료
# 41430, 266개 완료
# 41450, 459개 완료
# 41460, 0개 완료
# 41461, 395개 완료
# 41463, 1262개 완료
# 41465, 1131개 완료
# 41480, 833개 완료
# 41500, 223개 완료
# 41550, 279개 완료
# 41570, 1640개 완료
# 41590, 1518개 완료
# 41610, 597개 완료
# 41630, 341개 완료
# 41650, 111개 완료
# 41670, 99개 완료
# 41800, 24개 완료
# 41820, 21개 완료
# 41830, 71개 완료
# ******** 202007 완료 ********
# 11110, 49개 완료
# 11140, 76개 완료
# 11170, 114개 완료
# 11200, 211개 완료
# 11215, 99개 완료
# 11230, 212개 완료
# 11260, 167개 완료
# 11290, 255개 완료
# 11305, 97개 완료
# 11320, 208개 완료
# 11350, 401개 완료
# 11380, 196개 완료
# 11410, 182개 완료
# 11440, 218개 완료
# 11470, 205개 완료
# 11500, 419개 완료
# 11530, 270개 완료
# 11545, 93개 완료
# 11560, 213개 완료
# 11590, 229개 완료
# 11620, 119개 완료
# 11650, 295개 완료
# 11680, 240개 완료
# 11710, 291개 완료
# 11740, 319개 완료
# 41110, 0개 완료
# 41111, 259개 완료
# 41113, 365개 완료
# 41115, 107개 완료
# 41117, 449개 완료
# 41130, 0개 완료
# 41131, 101개 완료
# 41133, 123개 완료
# 41135, 418개 완료
# 41150, 665개 완료
# 41170, 0개 완료
# 41171, 173개 완료
# 41173, 402개 완료
# 41190, 623개 완료
# 41210, 224개 완료
# 41220, 599개 완료
# 41250, 130개 완료
# 41270, 0개 완료
# 41271, 209개 완료
# 41273, 263개 완료
# 41280, 0개 완료
# 41281, 453개 완료
# 41285, 297개 완료
# 41287, 483개 완료
# 41290, 15개 완료
# 41310, 167개 완료
# 41360, 798개 완료
# 41370, 337개 완료
# 41390, 565개 완료
# 41410, 221개 완료
# 41430, 149개 완료
# 41450, 244개 완료
# 41460, 0개 완료
# 41461, 304개 완료
# 41463, 648개 완료
# 41465, 591개 완료
# 41480, 935개 완료
# 41500, 192개 완료
# 41550, 210개 완료
# 41570, 1203개 완료
# 41590, 1042개 완료
# 41610, 409개 완료
# 41630, 249개 완료
# 41650, 89개 완료
# 41670, 90개 완료
# 41800, 17개 완료
# 41820, 21개 완료
# 41830, 59개 완료
# ******** 202008 완료 ********
# 11110, 36개 완료
# 11140, 56개 완료
# 11170, 107개 완료
# 11200, 149개 완료
# 11215, 76개 완료
# 11230, 167개 완료
# 11260, 110개 완료
# 11290, 149개 완료
# 11305, 82개 완료
# 11320, 155개 완료
# 11350, 324개 완료
# 11380, 154개 완료
# 11410, 158개 완료
# 11440, 172개 완료
# 11470, 163개 완료
# 11500, 318개 완료
# 11530, 228개 완료
# 11545, 69개 완료
# 11560, 161개 완료
# 11590, 151개 완료
# 11620, 119개 완료
# 11650, 209개 완료
# 11680, 191개 완료
# 11710, 231개 완료
# 11740, 211개 완료
# 41110, 0개 완료
# 41111, 215개 완료
# 41113, 292개 완료
# 41115, 95개 완료
# 41117, 451개 완료
# 41130, 0개 완료
# 41131, 86개 완료
# 41133, 103개 완료
# 41135, 380개 완료
# 41150, 603개 완료
# 41170, 0개 완료
# 41171, 153개 완료
# 41173, 313개 완료
# 41190, 548개 완료
# 41210, 203개 완료
# 41220, 655개 완료
# 41250, 137개 완료
# 41270, 0개 완료
# 41271, 186개 완료
# 41273, 215개 완료
# 41280, 0개 완료
# 41281, 393개 완료
# 41285, 292개 완료
# 41287, 473개 완료
# 41290, 18개 완료
# 41310, 131개 완료
# 41360, 751개 완료
# 41370, 367개 완료
# 41390, 565개 완료
# 41410, 238개 완료
# 41430, 106개 완료
# 41450, 178개 완료
# 41460, 0개 완료
# 41461, 306개 완료
# 41463, 494개 완료
# 41465, 490개 완료
# 41480, 950개 완료
# 41500, 193개 완료
# 41550, 234개 완료
# 41570, 1635개 완료
# 41590, 945개 완료
# 41610, 334개 완료
# 41630, 326개 완료
# 41650, 95개 완료
# 41670, 79개 완료
# 41800, 13개 완료
# 41820, 23개 완료
# 41830, 58개 완료
# ******** 202009 완료 ********
# 11110, 111개 완료
# 11140, 73개 완료
# 11170, 129개 완료
# 11200, 150개 완료
# 11215, 77개 완료
# 11230, 173개 완료
# 11260, 172개 완료
# 11290, 170개 완료
# 11305, 128개 완료
# 11320, 215개 완료
# 11350, 415개 완료
# 11380, 186개 완료
# 11410, 167개 완료
# 11440, 185개 완료
# 11470, 187개 완료
# 11500, 338개 완료
# 11530, 246개 완료
# 11545, 72개 완료
# 11560, 213개 완료
# 11590, 164개 완료
# 11620, 131개 완료
# 11650, 238개 완료
# 11680, 227개 완료
# 11710, 237개 완료
# 11740, 200개 완료
# 41110, 0개 완료
# 41111, 292개 완료
# 41113, 358개 완료
# 41115, 161개 완료
# 41117, 616개 완료
# 41130, 0개 완료
# 41131, 99개 완료
# 41133, 145개 완료
# 41135, 455개 완료
# 41150, 767개 완료
# 41170, 0개 완료
# 41171, 211개 완료
# 41173, 371개 완료
# 41190, 763개 완료
# 41210, 193개 완료
# 41220, 877개 완료
# 41250, 156개 완료
# 41270, 0개 완료
# 41271, 241개 완료
# 41273, 324개 완료
# 41280, 0개 완료
# 41281, 482개 완료
# 41285, 385개 완료
# 41287, 585개 완료
# 41290, 21개 완료
# 41310, 142개 완료
# 41360, 905개 완료
# 41370, 470개 완료
# 41390, 702개 완료
# 41410, 276개 완료
# 41430, 148개 완료
# 41450, 193개 완료
# 41460, 0개 완료
# 41461, 327개 완료
# 41463, 621개 완료
# 41465, 652개 완료
# 41480, 1202개 완료
# 41500, 231개 완료
# 41550, 323개 완료
# 41570, 2571개 완료
# 41590, 1222개 완료
# 41610, 428개 완료
# 41630, 387개 완료
# 41650, 106개 완료
# 41670, 109개 완료
# 41800, 12개 완료
# 41820, 23개 완료
# 41830, 69개 완료
# ******** 202010 완료 ********
# 11110, 64개 완료
# 11140, 79개 완료
# 11170, 148개 완료
# 11200, 231개 완료
# 11215, 109개 완료
# 11230, 245개 완료
# 11260, 174개 완료
# 11290, 271개 완료
# 11305, 108개 완료
# 11320, 308개 완료
# 11350, 640개 완료
# 11380, 231개 완료
# 11410, 202개 완료
# 11440, 266개 완료
# 11470, 249개 완료
# 11500, 464개 완료
# 11530, 483개 완료
# 11545, 123개 완료
# 11560, 276개 완료
# 11590, 224개 완료
# 11620, 183개 완료
# 11650, 338개 완료
# 11680, 440개 완료
# 11710, 380개 완료
# 11740, 337개 완료
# 41110, 0개 완료
# 41111, 354개 완료
# 41113, 476개 완료
# 41115, 207개 완료
# 41117, 799개 완료
# 41130, 0개 완료
# 41131, 119개 완료
# 41133, 139개 완료
# 41135, 806개 완료
# 41150, 950개 완료
# 41170, 0개 완료
# 41171, 292개 완료
# 41173, 695개 완료
# 41190, 881개 완료
# 41210, 260개 완료
# 41220, 903개 완료
# 41250, 199개 완료
# 41270, 0개 완료
# 41271, 318개 완료
# 41273, 354개 완료
# 41280, 0개 완료
# 41281, 853개 완료
# 41285, 714개 완료
# 41287, 1308개 완료
# 41290, 78개 완료
# 41310, 185개 완료
# 41360, 1159개 완료
# 41370, 408개 완료
# 41390, 832개 완료
# 41410, 376개 완료
# 41430, 259개 완료
# 41450, 258개 완료
# 41460, 0개 완료
# 41461, 336개 완료
# 41463, 820개 완료
# 41465, 954개 완료
# 41480, 1636개 완료
# 41500, 247개 완료
# 41550, 300개 완료
# 41570, 1113개 완료
# 41590, 1549개 완료
# 41610, 385개 완료
# 41630, 513개 완료
# 41650, 102개 완료
# 41670, 148개 완료
# 41800, 14개 완료
# 41820, 24개 완료
# 41830, 63개 완료
# ******** 202011 완료 ********
# 11110, 72개 완료
# 11140, 88개 완료
# 11170, 173개 완료
# 11200, 290개 완료
# 11215, 131개 완료
# 11230, 299개 완료
# 11260, 216개 완료
# 11290, 327개 완료
# 11305, 168개 완료
# 11320, 370개 완료
# 11350, 803개 완료
# 11380, 259개 완료
# 11410, 240개 완료
# 11440, 256개 완료
# 11470, 333개 완료
# 11500, 431개 완료
# 11530, 385개 완료
# 11545, 262개 완료
# 11560, 334개 완료
# 11590, 292개 완료
# 11620, 233개 완료
# 11650, 459개 완료
# 11680, 503개 완료
# 11710, 486개 완료
# 11740, 348개 완료
# 41110, 0개 완료
# 41111, 477개 완료
# 41113, 686개 완료
# 41115, 357개 완료
# 41117, 1111개 완료
# 41130, 0개 완료
# 41131, 133개 완료
# 41133, 148개 완료
# 41135, 668개 완료
# 41150, 966개 완료
# 41170, 0개 완료
# 41171, 296개 완료
# 41173, 789개 완료
# 41190, 1066개 완료
# 41210, 347개 완료
# 41220, 1353개 완료
# 41250, 530개 완료
# 41270, 0개 완료
# 41271, 339개 완료
# 41273, 608개 완료
# 41280, 0개 완료
# 41281, 1057개 완료
# 41285, 682개 완료
# 41287, 1052개 완료
# 41290, 74개 완료
# 41310, 225개 완료
# 41360, 1448개 완료
# 41370, 606개 완료
# 41390, 1110개 완료
# 41410, 717개 완료
# 41430, 400개 완료
# 41450, 407개 완료
# 41460, 0개 완료
# 41461, 403개 완료
# 41463, 1010개 완료
# 41465, 962개 완료
# 41480, 892개 완료
# 41500, 303개 완료
# 41550, 462개 완료
# 41570, 317개 완료
# 41590, 1897개 완료
# 41610, 416개 완료
# 41630, 726개 완료
# 41650, 142개 완료
# 41670, 112개 완료
# 41800, 18개 완료
# 41820, 23개 완료
# 41830, 67개 완료
# ******** 202012 완료 ********

# %%
apt_trade
# Out:
#       deal_amt build_y deal_y deal_m deal_day     dong                 apt_nm  \
# 0       85,000    2000   2020      3       18      청운동                   청운현대
# 1      116,000    2008   2020      3        3      사직동  광화문풍림스페이스본(101동~105동)
# 2      147,000    2004   2020      3        3      내수동                   킹스매너
# 3       96,091    2008   2020      3       31      견지동                대성스카이렉스
# 4       21,800    2003   2020      3       10      익선동                 현대뜨레비앙
# ..         ...     ...    ...    ...      ...      ...                    ...
# 62      14,200    2004   2020     12       19  용문면 다문리                   용문그린
# 63      32,000    2020   2020     12       19  용문면 다문리                   밀레니엄
# 64      31,500    2020   2020     12       20  용문면 다문리                   밀레니엄
# 65      31,500    2016   2020     12       24  용문면 다문리                  용문코아루
# 66      13,000    2004   2020     12       25  용문면 다문리                   용문그린
#
#    area_exc region_num region_code floor   sido sigungu
# 0     84.51      56-45       11110     3  서울특별시     종로구
# 1     95.88          9       11110     7  서울특별시     종로구
# 2    194.43     110-15       11110     7  서울특별시     종로구
# 3     149.8        110       11110     7  서울특별시     종로구
# 4      28.1         55       11110     8  서울특별시     종로구
# ..      ...        ...         ...   ...    ...     ...
# 62    59.74      691-6       41830    13    경기도     양평군
# 63   84.729     325-24       41830     5    경기도     양평군
# 64  84.9023     325-24       41830     9    경기도     양평군
# 65    76.11       1052       41830    12    경기도     양평군
# 66    59.74      691-6       41830     2    경기도     양평군
#
# [274027 rows x 13 columns]

# %%
apt_trade.to_csv('apt_trade_2018.csv', index=False)
